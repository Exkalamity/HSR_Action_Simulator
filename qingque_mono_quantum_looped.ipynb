# %%
import numpy as np
import pandas as pd
from characters.sparkle import Sparkle
from characters.qingque import Qingque
from characters.silver_wolf import Silver_Wolf
from characters.fu_xuan import Fu_Xuan
from simulations.qingque_mono_quantum_looped import QQ_Mono_Quantum, Initialize_QQ_Mono_Quantum
from utils.arena import Arena
from utils.data_table import Action_Table, Qingque_Statistics_Table, Qingque_Probability_Table

# %% [markdown]
# # Character Imports

# %%
qingque_speed = 135

# %%
silver_wolf_speed = 147

# %%
sparkle_speed = 134.1
bronya_lc = False
sparkle_tech = True
sparkle_turn_1_skill = True

# %%
fu_xuan_speed = 146
fu_xuan_technique = True

# %% [markdown]
# # Simulations

# %%
arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, bronya_lc=bronya_lc)

# %%
action_dataframe = Action_Table()
statistics_dataframe = Qingque_Statistics_Table()
probability_dataframe = Qingque_Probability_Table()
trials = 100

# %%
ult_sp_threshold = 5
for run in range(trials):
    print(f"\rRun number = {run}", end='')
    arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, sparkle_turn_1_skill = sparkle_turn_1_skill)
    QQ_Mono_Quantum(arena, qq, spk, sw, fx, action_df=action_dataframe, stat_df= statistics_dataframe, prob_df = probability_dataframe, run_num=run, cycles=5 , ult_sp_threshold = ult_sp_threshold)
# Out:
# Run number = 1
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# Run number = 9
# Run number = 99

# %% [markdown]
# # Results

# %%
#statistics_dataframe.df

# %%
df = statistics_dataframe.df.copy()
start = df["Turn"].min()
end = df["Turn"].max()
columns = df.columns[1:]
summary_df = pd.DataFrame(columns=columns)
for turn in range(start, end):
    df_copy = df.copy()
    df_turn = df_copy.loc[df["Turn"] == turn]

    new_row_dict = {}
    for col in columns:
        mean = round(df_turn[col].mean(),3)
        std = round(df_turn[col].std(),3)
        if std != 0:
            entry = f"{mean} ± {std}"
        else:
            entry = f"{mean}"
        new_row_dict[col] = [entry]
    new_row = pd.DataFrame.from_dict(new_row_dict)
    summary_df = pd.concat([summary_df, new_row], ignore_index= True)

# %%
summary_df_styled = summary_df.style.set_caption(f"Qingque speed = {qingque_speed}, Sparkle speed = {sparkle_speed}, Bronya_LC = {bronya_lc}, Silver Wolf Speed = {silver_wolf_speed}, Fu Xuan speed = {fu_xuan_speed}")
summary_df_styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_097e7">
#   <caption>Qingque speed = 135, Sparkle speed = 134.1, Bronya_LC = False, Silver Wolf Speed = 147, Fu Xuan speed = 146</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_097e7_level0_col0" class="col_heading level0 col0" >Turn</th>
#       <th id="T_097e7_level0_col1" class="col_heading level0 col1" >Cycle</th>
#       <th id="T_097e7_level0_col2" class="col_heading level0 col2" >Action Gauge</th>
#       <th id="T_097e7_level0_col3" class="col_heading level0 col3" >Current SP</th>
#       <th id="T_097e7_level0_col4" class="col_heading level0 col4" >Current Tiles</th>
#       <th id="T_097e7_level0_col5" class="col_heading level0 col5" ># Draws</th>
#       <th id="T_097e7_level0_col6" class="col_heading level0 col6" >Hidden Hand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_097e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_097e7_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_097e7_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_097e7_row0_col2" class="data row0 col2" >74.074</td>
#       <td id="T_097e7_row0_col3" class="data row0 col3" >7.0</td>
#       <td id="T_097e7_row0_col4" class="data row0 col4" >3.0</td>
#       <td id="T_097e7_row0_col5" class="data row0 col5" >2.56 ± 1.297</td>
#       <td id="T_097e7_row0_col6" class="data row0 col6" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_097e7_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_097e7_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_097e7_row1_col2" class="data row1 col2" >111.211</td>
#       <td id="T_097e7_row1_col3" class="data row1 col3" >4.44 ± 1.297</td>
#       <td id="T_097e7_row1_col4" class="data row1 col4" >2.0</td>
#       <td id="T_097e7_row1_col5" class="data row1 col5" >3.03 ± 1.123</td>
#       <td id="T_097e7_row1_col6" class="data row1 col6" >0.87 ± 0.338</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_097e7_row2_col0" class="data row2 col0" >3.0</td>
#       <td id="T_097e7_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_097e7_row2_col2" class="data row2 col2" >149.242</td>
#       <td id="T_097e7_row2_col3" class="data row2 col3" >6.78 ± 1.375</td>
#       <td id="T_097e7_row2_col4" class="data row2 col4" >4.26 ± 0.676</td>
#       <td id="T_097e7_row2_col5" class="data row2 col5" >2.24 ± 1.512</td>
#       <td id="T_097e7_row2_col6" class="data row2 col6" >0.98 ± 0.141</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_097e7_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_097e7_row3_col1" class="data row3 col1" >1.0</td>
#       <td id="T_097e7_row3_col2" class="data row3 col2" >223.317</td>
#       <td id="T_097e7_row3_col3" class="data row3 col3" >5.93 ± 1.908</td>
#       <td id="T_097e7_row3_col4" class="data row3 col4" >3.08 ± 0.563</td>
#       <td id="T_097e7_row3_col5" class="data row3 col5" >2.55 ± 1.266</td>
#       <td id="T_097e7_row3_col6" class="data row3 col6" >0.94 ± 0.239</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_097e7_row4_col0" class="data row4 col0" >5.0</td>
#       <td id="T_097e7_row4_col1" class="data row4 col1" >2.0</td>
#       <td id="T_097e7_row4_col2" class="data row4 col2" >262.67 ± 8.816</td>
#       <td id="T_097e7_row4_col3" class="data row4 col3" >4.11 ± 2.374</td>
#       <td id="T_097e7_row4_col4" class="data row4 col4" >2.3 ± 1.193</td>
#       <td id="T_097e7_row4_col5" class="data row4 col5" >2.69 ± 1.089</td>
#       <td id="T_097e7_row4_col6" class="data row4 col6" >0.67 ± 0.473</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_097e7_row5_col0" class="data row5 col0" >6.0</td>
#       <td id="T_097e7_row5_col1" class="data row5 col1" >2.01 ± 0.1</td>
#       <td id="T_097e7_row5_col2" class="data row5 col2" >300.923 ± 10.65</td>
#       <td id="T_097e7_row5_col3" class="data row5 col3" >2.53 ± 2.504</td>
#       <td id="T_097e7_row5_col4" class="data row5 col4" >4.61 ± 1.27</td>
#       <td id="T_097e7_row5_col5" class="data row5 col5" >1.65 ± 1.048</td>
#       <td id="T_097e7_row5_col6" class="data row5 col6" >0.51 ± 0.502</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_097e7_row6_col0" class="data row6 col0" >7.0</td>
#       <td id="T_097e7_row6_col1" class="data row6 col1" >3.0</td>
#       <td id="T_097e7_row6_col2" class="data row6 col2" >372.845 ± 3.613</td>
#       <td id="T_097e7_row6_col3" class="data row6 col3" >3.45 ± 2.447</td>
#       <td id="T_097e7_row6_col4" class="data row6 col4" >5.55 ± 2.732</td>
#       <td id="T_097e7_row6_col5" class="data row6 col5" >2.11 ± 1.363</td>
#       <td id="T_097e7_row6_col6" class="data row6 col6" >0.87 ± 0.338</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_097e7_row7_col0" class="data row7 col0" >8.0</td>
#       <td id="T_097e7_row7_col1" class="data row7 col1" >3.0</td>
#       <td id="T_097e7_row7_col2" class="data row7 col2" >416.649 ± 14.636</td>
#       <td id="T_097e7_row7_col3" class="data row7 col3" >4.09 ± 1.918</td>
#       <td id="T_097e7_row7_col4" class="data row7 col4" >4.04 ± 2.835</td>
#       <td id="T_097e7_row7_col5" class="data row7 col5" >2.39 ± 1.23</td>
#       <td id="T_097e7_row7_col6" class="data row7 col6" >0.86 ± 0.349</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_097e7_row8_col0" class="data row8 col0" >9.0</td>
#       <td id="T_097e7_row8_col1" class="data row8 col1" >3.31 ± 0.465</td>
#       <td id="T_097e7_row8_col2" class="data row8 col2" >459.505 ± 18.69</td>
#       <td id="T_097e7_row8_col3" class="data row8 col3" >2.99 ± 2.101</td>
#       <td id="T_097e7_row8_col4" class="data row8 col4" >3.84 ± 1.656</td>
#       <td id="T_097e7_row8_col5" class="data row8 col5" >2.23 ± 0.993</td>
#       <td id="T_097e7_row8_col6" class="data row8 col6" >0.68 ± 0.469</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_097e7_row9_col0" class="data row9 col0" >10.0</td>
#       <td id="T_097e7_row9_col1" class="data row9 col1" >4.12 ± 0.327</td>
#       <td id="T_097e7_row9_col2" class="data row9 col2" >526.432 ± 13.347</td>
#       <td id="T_097e7_row9_col3" class="data row9 col3" >2.16 ± 2.107</td>
#       <td id="T_097e7_row9_col4" class="data row9 col4" >4.15 ± 2.376</td>
#       <td id="T_097e7_row9_col5" class="data row9 col5" >1.8 ± 1.015</td>
#       <td id="T_097e7_row9_col6" class="data row9 col6" >0.6 ± 0.492</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_097e7_row10_col0" class="data row10 col0" >11.0</td>
#       <td id="T_097e7_row10_col1" class="data row10 col1" >5.0</td>
#       <td id="T_097e7_row10_col2" class="data row10 col2" >579.229 ± 20.715</td>
#       <td id="T_097e7_row10_col3" class="data row10 col3" >2.37 ± 2.048</td>
#       <td id="T_097e7_row10_col4" class="data row10 col4" >4.87 ± 1.968</td>
#       <td id="T_097e7_row10_col5" class="data row10 col5" >1.81 ± 0.961</td>
#       <td id="T_097e7_row10_col6" class="data row10 col6" >0.62 ± 0.488</td>
#     </tr>
#     <tr>
#       <th id="T_097e7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_097e7_row11_col0" class="data row11 col0" >12.0</td>
#       <td id="T_097e7_row11_col1" class="data row11 col1" >5.299 ± 0.46</td>
#       <td id="T_097e7_row11_col2" class="data row11 col2" >632.867 ± 28.857</td>
#       <td id="T_097e7_row11_col3" class="data row11 col3" >3.381 ± 1.981</td>
#       <td id="T_097e7_row11_col4" class="data row11 col4" >5.32 ± 3.433</td>
#       <td id="T_097e7_row11_col5" class="data row11 col5"

# %%
action_df = action_dataframe.df

# %%
sparkle_action_df = action_df.loc[(action_df["Name"] == "Sparkle")].copy()

# %%
sparkle_action_df.iloc[:30]
# Out:
#         Name  Cycle  Action Gauge Current SP  Current Energy    Action SP Gain
# 3    Sparkle    0.0     74.571216          3           55.00     Skill      -1
# 7    Sparkle    0.0    149.142431          4           90.82     Skill      -1
# 8    Sparkle    0.0    149.242431          3          126.64  Ultimate       4
# 13   Sparkle    1.0    223.713647          5            5.00     Skill      -1
# 17   Sparkle    2.0    298.284862          3           40.82     Skill      -1
# 22   Sparkle    3.0    372.856078          1           76.64     Skill      -1
# 24   Sparkle    3.0    409.595973         -1          112.46  Ultimate       4
# 27   Sparkle    3.0    447.427293          4            5.00     Skill      -1
# 32   Sparkle    4.0    521.998509          1           40.82     Skill      -1
# 36   Sparkle    5.0    596.569724          1           76.64     Skill      -1
# 37   Sparkle    5.0    596.669724          0          112.46  Ultimate       4
# 45   Sparkle    0.0     74.571216          7           55.00     Skill      -1
# 49   Sparkle    0.0    149.142431          6           90.82     Skill      -1
# 54   Sparkle    1.0    223.713647          5          120.00  Ultimate       4
# 55   Sparkle    1.0    223.713647          9            5.00     Skill      -1
# 59   Sparkle    2.0    298.284862          5           40.82     Skill      -1
# 64   Sparkle    3.0    372.856078          2           76.64     Skill      -1
# 66   Sparkle    3.0    409.595973          0          112.46  Ultimate       4
# 69   Sparkle    3.0    447.427293          5            5.00     Skill      -1
# 74   Sparkle    4.0    521.998509          1           40.82     Skill      -1
# 78   Sparkle    5.0    596.569724         -1           76.64     Basic       1
# 81   Sparkle    5.0    632.812478         -2          112.46  Ultimate       4
# 83   Sparkle    6.0    671.140940          1            5.00     Skill      -1
# 87   Sparkle    0.0     74.571216          5           55.00     Skill      -1
# 91   Sparkle    0.0    149.142431          3           90.82     Skill      -1
# 92   Sparkle    0.0    149.242431          2          126.64  Ultimate       4
# 97   Sparkle    1.0    223.713647          5            5.00     Skill      -1
# 101  Sparkle    2.0    298.284862          3           40.82     Skill      -1
# 106  Sparkle    3.0    372.856078          2           76.64     Skill      -1
# 108  Sparkle    3.0    409.595973          0          112.46  Ultimate       4

# %%
spk_ult_df = sparkle_action_df.loc[sparkle_action_df["Action"] == "Ultimate"]

# %%
len(spk_ult_df.loc[spk_ult_df["Current Energy"] == 120.00])/len(spk_ult_df)
# Out:
# 0.22635135135135134

# %%
action_df.loc[(action_df["Name"] != "Fu Xuan") & (action_df["Name"] != "Silver Wolf")].iloc[:20]
# Out:
#        Name  Cycle  Action Gauge Current SP  Current Energy          Action  \
# 2   Qingque    0.0     74.074074          7           70.00  Enhanced Basic
# 3   Sparkle    0.0     74.571216          3           55.00           Skill
# 4   Qingque    0.0    111.211111          2           70.00  Enhanced Basic
# 7   Sparkle    0.0    149.142431          4           90.82           Skill
# 8   Sparkle    0.0    149.242431          3          126.64        Ultimate
# 9   Qingque    0.0    149.242431          7           70.00  Enhanced Basic
# 12  Qingque    1.0    223.316505          6           70.00  Enhanced Basic
# 13  Sparkle    1.0    223.713647          5            5.00           Skill
# 14  Qingque    2.0    260.453542          4           70.00  Enhanced Basic
# 17  Sparkle    2.0    298.284862          3           40.82           Skill
# 18  Qingque    2.0    298.384862          2           70.00           Basic
# 21  Qingque    3.0    372.458936          1           70.00  Enhanced Basic
# 22  Sparkle    3.0    372.856078          1           76.64           Skill
# 24  Sparkle    3.0    409.595973         -1          112.46        Ultimate
# 25  Qingque    3.0    409.595973          3           70.00  Enhanced Basic
# 27  Sparkle    3.0    447.427293          4            5.00           Skill
# 28  Qingque    3.0    447.527293          3           70.00  Enhanced Basic
# 31  Qingque    4.0    521.601367          2           70.00  Enhanced Basic
# 32  Sparkle    4.0    521.998509          1           40.82           Skill
# 35  Qingque    5.0    558.738404          2           70.00  Enhanced Basic
#
#    SP Gain
# 2        4
# 3       -1
# 4        0
# 7       -1
# 8        4
# 9        1
# 12       1
# 13      -1
# 14       1
# 17      -1
# 18       3
# 21       0
# 22      -1
# 24       4
# 25       0
# 27      -1
# 28       1
# 31       1
# 32      -1
# 35       1

# %%
statistics_dataframe.df.iloc[:20]
# Out:
#    Sim # Turn  Cycle  Action Gauge Current SP Current Tiles # Draws  \
# 0      0    1    0.0     74.074074          7             3       5
# 1      0    2    0.0    111.211111          2             2       1
# 2      0    3    0.0    149.242431          7             4       2
# 3      0    4    1.0    223.316505          6             3       2
# 4      0    5    2.0    260.453542          4             2       2
# 5      0    6    2.0    298.384862          2             4       3
# 6      0    7    3.0    372.458936          1             7       1
# 7      0    8    3.0    409.595973          3             3       1
# 8      0    9    3.0    447.527293          3             3       2
# 9      0   10    4.0    521.601367          2             3       2
# 10     0   11    5.0    558.738404          2             4       2
# 11     0   12    5.0    596.669724          4             2       2
# 12     0   13    6.0    670.743798          3             3       2
# 13     1    1    0.0     74.074074          7             3       1
# 14     1    2    0.0    111.211111          6             2       3
# 15     1    3    0.0    149.242431          8             4       1
# 16     1    4    1.0    223.316505          8             3       4
# 17     1    5    2.0    260.453542          7             2       5
# 18     1    6    2.0    298.384862          4             4       3
# 19     1    7    3.0    372.458936          4             3       3
#
#    Hidden Hand
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5        False
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
