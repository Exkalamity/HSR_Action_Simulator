# %%
import numpy as np
import pandas as pd
from characters.sparkle import Sparkle
from characters.qingque import Qingque
from characters.silver_wolf import Silver_Wolf
from characters.fu_xuan import Fu_Xuan
from simulations.qingque_mono_quantum_looped import QQ_Mono_Quantum, Initialize_QQ_Mono_Quantum
from utils.arena import Arena
from utils.data_table import Action_Table, Qingque_Statistics_Table, Qingque_Probability_Table

# %% [markdown]
# # Character Imports

# %%
qingque_speed = 98

# %%
silver_wolf_speed = 161

# %%
sparkle_speed = 160.1
bronya_lc = False
sparkle_tech = True
sparkle_turn_1_skill = True

# %%
fu_xuan_speed = 134
fu_xuan_technique = True

# %% [markdown]
# # Simulations

# %%
arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, bronya_lc=bronya_lc)

# %%
action_dataframe = Action_Table()
statistics_dataframe = Qingque_Statistics_Table()
probability_dataframe = Qingque_Probability_Table()
trials = 100

# %%
for run in range(trials):
    print(f"\rRun number = {run}", end='')
    arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, sparkle_turn_1_skill = sparkle_turn_1_skill)
    QQ_Mono_Quantum(arena, qq, spk, sw, fx, action_df=action_dataframe, stat_df= statistics_dataframe, prob_df = probability_dataframe, run_num=run, cycles=5)
# Out:
# Run number = 1
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# Run number = 9
# Run number = 99

# %% [markdown]
# # Results

# %%
#statistics_dataframe.df

# %%
df = statistics_dataframe.df.copy()
start = df["Turn"].min()
end = df["Turn"].max()
columns = df.columns[1:]
summary_df = pd.DataFrame(columns=columns)
for turn in range(start, end):
    df_copy = df.copy()
    df_turn = df_copy.loc[df["Turn"] == turn]

    new_row_dict = {}
    for col in columns:
        mean = round(df_turn[col].mean(),3)
        std = round(df_turn[col].std(),3)
        if std != 0:
            entry = f"{mean} ± {std}"
        else:
            entry = f"{mean}"
        new_row_dict[col] = [entry]
    new_row = pd.DataFrame.from_dict(new_row_dict)
    summary_df = pd.concat([summary_df, new_row], ignore_index= True)

# %%
summary_df_styled = summary_df.style.set_caption(f"Qingque speed = {qingque_speed}, Sparkle speed = {sparkle_speed}, Bronya_LC = {bronya_lc}, Silver Wolf Speed = {silver_wolf_speed}, Fu Xuan speed = {fu_xuan_speed}")
summary_df_styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_81f9c">
#   <caption>Qingque speed = 98, Sparkle speed = 160.1, Bronya_LC = False, Silver Wolf Speed = 161, Fu Xuan speed = 134</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81f9c_level0_col0" class="col_heading level0 col0" >Turn</th>
#       <th id="T_81f9c_level0_col1" class="col_heading level0 col1" >Cycle</th>
#       <th id="T_81f9c_level0_col2" class="col_heading level0 col2" >Action Gauge</th>
#       <th id="T_81f9c_level0_col3" class="col_heading level0 col3" >Current SP</th>
#       <th id="T_81f9c_level0_col4" class="col_heading level0 col4" >Current Tiles</th>
#       <th id="T_81f9c_level0_col5" class="col_heading level0 col5" ># Draws</th>
#       <th id="T_81f9c_level0_col6" class="col_heading level0 col6" >Hidden Hand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81f9c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81f9c_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_81f9c_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_81f9c_row0_col2" class="data row0 col2" >62.561</td>
#       <td id="T_81f9c_row0_col3" class="data row0 col3" >5.0</td>
#       <td id="T_81f9c_row0_col4" class="data row0 col4" >3.0</td>
#       <td id="T_81f9c_row0_col5" class="data row0 col5" >2.76 ± 1.304</td>
#       <td id="T_81f9c_row0_col6" class="data row0 col6" >0.93 ± 0.256</td>
#     </tr>
#     <tr>
#       <th id="T_81f9c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81f9c_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_81f9c_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_81f9c_row1_col2" class="data row1 col2" >125.022</td>
#       <td id="T_81f9c_row1_col3" class="data row1 col3" >6.75 ± 0.783</td>
#       <td id="T_81f9c_row1_col4" class="data row1 col4" >4.21 ± 0.769</td>
#       <td id="T_81f9c_row1_col5" class="data row1 col5" >2.06 ± 1.118</td>
#       <td id="T_81f9c_row1_col6" class="data row1 col6" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_81f9c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_81f9c_row2_col0" class="data row2 col0" >3.0</td>
#       <td id="T_81f9c_row2_col1" class="data row2 col1" >1.0</td>
#       <td id="T_81f9c_row2_col2" class="data row2 col2" >187.483</td>
#       <td id="T_81f9c_row2_col3" class="data row2 col3" >5.78 ± 0.543</td>
#       <td id="T_81f9c_row2_col4" class="data row2 col4" >4.0</td>
#       <td id="T_81f9c_row2_col5" class="data row2 col5" >2.37 ± 1.361</td>
#       <td id="T_81f9c_row2_col6" class="data row2 col6" >0.99 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_81f9c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_81f9c_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_81f9c_row3_col1" class="data row3 col1" >1.04 ± 0.197</td>
#       <td id="T_81f9c_row3_col2" class="data row3 col2" >251.527 ± 7.795</td>
#       <td id="T_81f9c_row3_col3" class="data row3 col3" >1.6 ± 1.101</td>
#       <td id="T_81f9c_row3_col4" class="data row3 col4" >4.04 ± 0.4</td>
#       <td id="T_81f9c_row3_col5" class="data row3 col5" >1.83 ± 0.954</td>
#       <td id="T_81f9c_row3_col6" class="data row3 col6" >0.47 ± 0.502</td>
#     </tr>
#     <tr>
#       <th id="T_81f9c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_81f9c_row4_col0" class="data row4 col0" >5.0</td>
#       <td id="T_81f9c_row4_col1" class="data row4 col1" >2.0</td>
#       <td id="T_81f9c_row4_col2" class="data row4 col2" >313.534 ± 5.562</td>
#       <td id="T_81f9c_row4_col3" class="data row4 col3" >5.15 ± 1.274</td>
#       <td id="T_81f9c_row4_col4" class="data row4 col4" >6.16 ± 2.083</td>
#       <td id="T_81f9c_row4_col5" class="data row4 col5" >1.7 ± 1.04</td>
#       <td id="T_81f9c_row4_col6" class="data row4 col6" >0.99 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_81f9c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_81f9c_row5_col0" class="data row5 col0" >6.0</td>
#       <td id="T_81f9c_row5_col1" class="data row5 col1" >3.0</td>
#       <td id="T_81f9c_row5_col2" class="data row5 col2" >375.542 ± 3.328</td>
#       <td id="T_81f9c_row5_col3" class="data row5 col3" >5.03 ± 1.15</td>
#       <td id="T_81f9c_row5_col4" class="data row5 col4" >4.04 ± 0.4</td>
#       <td id="T_81f9c_row5_col5" class="data row5 col5" >2.36 ± 1.382</td>
#       <td id="T_81f9c_row5_col6" class="data row5 col6" >0.89 ± 0.314</td>
#     </tr>
#     <tr>
#       <th id="T_81f9c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_81f9c_row6_col0" class="data row6 col0" >7.0</td>
#       <td id="T_81f9c_row6_col1" class="data row6 col1" >3.15 ± 0.359</td>
#       <td id="T_81f9c_row6_col2" class="data row6 col2" >443.486 ± 14.152</td>
#       <td id="T_81f9c_row6_col3" class="data row6 col3" >2.31 ± 0.961</td>
#       <td id="T_81f9c_row6_col4" class="data row6 col4" >3.63 ± 1.727</td>
#       <td id="T_81f9c_row6_col5" class="data row6 col5" >2.33 ± 0.975</td>
#       <td id="T_81f9c_row6_col6" class="data row6 col6" >0.6 ± 0.492</td>
#     </tr>
#     <tr>
#       <th id="T_81f9c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_81f9c_row7_col0" class="data row7 col0" >8.0</td>
#       <td id="T_81f9c_row7_col1" class="data row7 col1" >4.02 ± 0.141</td>
#       <td id="T_81f9c_row7_col2" class="data row7 col2" >504.708 ± 12.613</td>
#       <td id="T_81f9c_row7_col3" class="data row7 col3" >5.1 ± 1.425</td>
#       <td id="T_81f9c_row7_col4" class="data row7 col4" >5.24 ± 1.471</td>
#       <td id="T_81f9c_row7_col5" class="data row7 col5" >1.86 ± 1.247</td>
#       <td id="T_81f9c_row7_col6" class="data row7 col6" >0.98 ± 0.141</td>
#     </tr>
#     <tr>
#       <th id="T_81f9c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_81f9c_row8_col0" class="data row8 col0" >9.0</td>
#       <td id="T_81f9c_row8_col1" class="data row8 col1" >5.0</td>
#       <td id="T_81f9c_row8_col2" class="data row8 col2" >566.15 ± 11.724</td>
#       <td id="T_81f9c_row8_col3" class="data row8 col3" >3.34 ± 1.539</td>
#       <td id="T_81f9c_row8_col4" class="data row8 col4" >3.98 ± 0.804</td>
#       <td id="T_81f9c_row8_col5" class="data row8 col5" >2.08 ± 0.971</td>
#       <td id="T_81f9c_row8_col6" class="data row8 col6" >0.79 ± 0.409</td>
#     </tr>
#   </tbody>
# </table>

# %%
action_df = action_dataframe.df

# %%
action_df.loc[(action_df["Name"] == "Silver Wolf")].iloc[:20]
# Out:
#            Name  Cycle  Action Gauge Current SP  Current Energy Action SP Gain
# 0   Silver Wolf    0.0     62.111801          6            55.0  Skill      -1
# 4   Silver Wolf    0.0    124.223602          4            55.0  Basic       1
# 9   Silver Wolf    1.0    186.335404          7            55.0  Basic       1
# 13  Silver Wolf    1.0    248.447205          5            55.0  Skill      -1
# 17  Silver Wolf    2.0    310.559006          0            55.0  Basic       1
# 21  Silver Wolf    3.0    372.670807          4            55.0  Basic       1
# 25  Silver Wolf    3.0    434.782609         -1            55.0  Basic       1
# 29  Silver Wolf    4.0    496.894410          1            55.0  Skill      -1
# 33  Silver Wolf    5.0    559.006211          4            55.0  Basic       1
# 37  Silver Wolf    5.0    621.118012          5            55.0  Basic       1
# 41  Silver Wolf    0.0     62.111801          6            55.0  Skill      -1
# 45  Silver Wolf    0.0    124.223602          2            55.0  Basic       1
# 50  Silver Wolf    1.0    186.335404          6            55.0  Basic       1
# 54  Silver Wolf    1.0    248.447205          4            55.0  Skill      -1
# 58  Silver Wolf    2.0    310.559006          2            55.0  Basic       1
# 62  Silver Wolf    3.0    372.670807          3            55.0  Basic       1
# 66  Silver Wolf    3.0    434.782609          3            55.0  Skill      -1
# 70  Silver Wolf    4.0    496.894410          0            55.0  Basic       1
# 75  Silver Wolf    5.0    559.006211          3            55.0  Basic       1
# 79  Silver Wolf    5.0    621.118012          2            55.0  Skill      -1

# %%
action_df.loc[(action_df["Name"] != "Fu Xuan") & (action_df["Name"] != "Silver Wolf")].iloc[:20]
# Out:
#        Name  Cycle  Action Gauge Current SP  Current Energy          Action  \
# 1   Sparkle    0.0     62.460962          5           55.00           Skill
# 2   Qingque    0.0     62.560962          5           70.00  Enhanced Basic
# 5   Sparkle    0.0    124.921924          5           90.82           Skill
# 6   Sparkle    0.0    124.921924          4          126.64        Ultimate
# 7   Qingque    0.0    125.021924          7           70.00  Enhanced Basic
# 10  Sparkle    1.0    187.382886          7            5.00           Skill
# 11  Qingque    1.0    187.482886          6           70.00  Enhanced Basic
# 14  Sparkle    1.0    249.843848          4           40.82           Skill
# 15  Qingque    1.0    249.943848          3           70.00           Basic
# 18  Sparkle    2.0    312.304809          1           76.64           Skill
# 19  Sparkle    2.0    312.304809          0          112.46        Ultimate
# 20  Qingque    2.0    312.404809          4           70.00  Enhanced Basic
# 23  Sparkle    3.0    374.765771          6            5.00           Skill
# 24  Qingque    3.0    374.865771          5           70.00           Basic
# 26  Sparkle    3.0    437.226733          0           40.82           Basic
# 28  Qingque    4.0    476.906588          2           70.00  Enhanced Basic
# 30  Sparkle    4.0    499.687695          0           76.64           Basic
# 31  Sparkle    4.0    499.687695          1          112.46        Ultimate
# 34  Sparkle    5.0    562.148657          5            5.00           Skill
# 35  Qingque    5.0    562.248657          4           70.00  Enhanced Basic
#
#    SP Gain
# 1       -1
# 2        2
# 5       -1
# 6        4
# 7        0
# 10      -1
# 11       0
# 14      -1
# 15       4
# 18      -1
# 19       4
# 20       0
# 23      -1
# 24       6
# 26       1
# 28       1
# 30       1
# 31       4
# 34      -1
# 35       0

# %%
statistics_dataframe.df.iloc[:20]
# Out:
#    Sim # Turn  Cycle  Action Gauge Current SP Current Tiles # Draws  \
# 0      0    1    0.0     62.560962          5             3       3
# 1      0    2    0.0    125.021924          7             4       1
# 2      0    3    1.0    187.482886          6             4       1
# 3      0    4    1.0    249.943848          3             4       4
# 4      0    5    2.0    312.404809          4             8       1
# 5      0    6    3.0    374.865771          5             4       6
# 6      0    7    4.0    476.906588          2             8       2
# 7      0    8    5.0    562.248657          4             6       1
# 8      0    9    5.0    624.709619          5             4       2
# 9      1    1    0.0     62.560962          5             3       5
# 10     1    2    0.0    125.021924          6             4       2
# 11     1    3    1.0    187.482886          6             4       2
# 12     1    4    1.0    249.943848          2             4       2
# 13     1    5    2.0    312.404809          6             4       4
# 14     1    6    3.0    374.865771          4             4       2
# 15     1    7    3.0    437.326733          1             3       2
# 16     1    8    4.0    499.787695          4             7       1
# 17     1    9    5.0    562.248657          3             4       3
# 18     1   10    5.0    624.709619          0             4       1
# 19     2    1    0.0     62.560962          5             3       3
#
#    Hidden Hand
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
# 5        False
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15       False
# 16        True
# 17        True
# 18       False
# 19        True
