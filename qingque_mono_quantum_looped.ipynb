# %%
import numpy as np
import pandas as pd
from characters.sparkle import Sparkle
from characters.qingque import Qingque
from characters.silver_wolf import Silver_Wolf
from characters.fu_xuan import Fu_Xuan
from simulations.qingque_mono_quantum_looped import QQ_Mono_Quantum, Initialize_QQ_Mono_Quantum
from utils.arena import Arena
from utils.data_table import Action_Table, Qingque_Statistics_Table, Qingque_Probability_Table

# %% [markdown]
# # Character Imports

# %%
qingque_speed = 98

# %%
silver_wolf_speed = 146

# %%
sparkle_speed = 161
bronya_lc = False
sparkle_tech = True
sparkle_turn_1_skill = True

# %%
fu_xuan_speed = 142
fu_xuan_technique = True

# %% [markdown]
# # Simulations

# %%
arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, bronya_lc=bronya_lc)

# %%
action_dataframe = Action_Table()
statistics_dataframe = Qingque_Statistics_Table()
probability_dataframe = Qingque_Probability_Table()
trials = 100

# %%
ult_sp_threshold = 5
for run in range(trials):
    print(f"\rRun number = {run}", end='')
    arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, sparkle_turn_1_skill = sparkle_turn_1_skill)
    QQ_Mono_Quantum(arena, qq, spk, sw, fx, action_df=action_dataframe, stat_df= statistics_dataframe, prob_df = probability_dataframe, run_num=run, cycles=5 , ult_sp_threshold = ult_sp_threshold)
# Out:
# Run number = 1
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# Run number = 7
# Run number = 99

# %% [markdown]
# # Results

# %%
#statistics_dataframe.df

# %%
df = statistics_dataframe.df.copy()
start = df["Turn"].min()
end = df["Turn"].max()
columns = df.columns[1:]
summary_df = pd.DataFrame(columns=columns)
for turn in range(start, end):
    df_copy = df.copy()
    df_turn = df_copy.loc[df["Turn"] == turn]

    new_row_dict = {}
    for col in columns:
        mean = round(df_turn[col].mean(),3)
        std = round(df_turn[col].std(),3)
        if std != 0:
            entry = f"{mean} ± {std}"
        else:
            entry = f"{mean}"
        new_row_dict[col] = [entry]
    new_row = pd.DataFrame.from_dict(new_row_dict)
    summary_df = pd.concat([summary_df, new_row], ignore_index= True)

# %%
summary_df_styled = summary_df.style.set_caption(f"Qingque speed = {qingque_speed}, Sparkle speed = {sparkle_speed},  Silver Wolf Speed = {silver_wolf_speed}, Fu Xuan speed = {fu_xuan_speed}")
summary_df_styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_68a69">
#   <caption>Qingque speed = 98, Sparkle speed = 161,  Silver Wolf Speed = 146, Fu Xuan speed = 142</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68a69_level0_col0" class="col_heading level0 col0" >Turn</th>
#       <th id="T_68a69_level0_col1" class="col_heading level0 col1" >Cycle</th>
#       <th id="T_68a69_level0_col2" class="col_heading level0 col2" >Action Gauge</th>
#       <th id="T_68a69_level0_col3" class="col_heading level0 col3" >Current SP</th>
#       <th id="T_68a69_level0_col4" class="col_heading level0 col4" >Current Tiles</th>
#       <th id="T_68a69_level0_col5" class="col_heading level0 col5" ># Draws</th>
#       <th id="T_68a69_level0_col6" class="col_heading level0 col6" >Hidden Hand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68a69_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68a69_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_68a69_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_68a69_row0_col2" class="data row0 col2" >62.212</td>
#       <td id="T_68a69_row0_col3" class="data row0 col3" >6.0</td>
#       <td id="T_68a69_row0_col4" class="data row0 col4" >2.0</td>
#       <td id="T_68a69_row0_col5" class="data row0 col5" >3.16 ± 1.308</td>
#       <td id="T_68a69_row0_col6" class="data row0 col6" >0.99 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68a69_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_68a69_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_68a69_row1_col2" class="data row1 col2" >124.324</td>
#       <td id="T_68a69_row1_col3" class="data row1 col3" >6.52 ± 0.99</td>
#       <td id="T_68a69_row1_col4" class="data row1 col4" >4.02 ± 0.2</td>
#       <td id="T_68a69_row1_col5" class="data row1 col5" >2.3 ± 1.299</td>
#       <td id="T_68a69_row1_col6" class="data row1 col6" >0.98 ± 0.141</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68a69_row2_col0" class="data row2 col0" >3.0</td>
#       <td id="T_68a69_row2_col1" class="data row2 col1" >1.0</td>
#       <td id="T_68a69_row2_col2" class="data row2 col2" >186.435</td>
#       <td id="T_68a69_row2_col3" class="data row2 col3" >4.77 ± 1.994</td>
#       <td id="T_68a69_row2_col4" class="data row2 col4" >4.08 ± 0.563</td>
#       <td id="T_68a69_row2_col5" class="data row2 col5" >2.05 ± 0.936</td>
#       <td id="T_68a69_row2_col6" class="data row2 col6" >0.89 ± 0.314</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_68a69_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_68a69_row3_col1" class="data row3 col1" >1.1 ± 0.302</td>
#       <td id="T_68a69_row3_col2" class="data row3 col2" >252.54 ± 12.039</td>
#       <td id="T_68a69_row3_col3" class="data row3 col3" >2.07 ± 1.986</td>
#       <td id="T_68a69_row3_col4" class="data row3 col4" >4.72 ± 1.621</td>
#       <td id="T_68a69_row3_col5" class="data row3 col5" >1.78 ± 1.001</td>
#       <td id="T_68a69_row3_col6" class="data row3 col6" >0.49 ± 0.502</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_68a69_row4_col0" class="data row4 col0" >5.0</td>
#       <td id="T_68a69_row4_col1" class="data row4 col1" >2.03 ± 0.171</td>
#       <td id="T_68a69_row4_col2" class="data row4 col2" >314.548 ± 12.682</td>
#       <td id="T_68a69_row4_col3" class="data row4 col3" >4.72 ± 1.181</td>
#       <td id="T_68a69_row4_col4" class="data row4 col4" >6.51 ± 3.18</td>
#       <td id="T_68a69_row4_col5" class="data row4 col5" >1.93 ± 1.335</td>
#       <td id="T_68a69_row4_col6" class="data row4 col6" >0.96 ± 0.197</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_68a69_row5_col0" class="data row5 col0" >6.0</td>
#       <td id="T_68a69_row5_col1" class="data row5 col1" >3.0</td>
#       <td id="T_68a69_row5_col2" class="data row5 col2" >375.89 ± 11.395</td>
#       <td id="T_68a69_row5_col3" class="data row5 col3" >2.53 ± 1.642</td>
#       <td id="T_68a69_row5_col4" class="data row5 col4" >4.22 ± 1.203</td>
#       <td id="T_68a69_row5_col5" class="data row5 col5" >1.99 ± 1.133</td>
#       <td id="T_68a69_row5_col6" class="data row5 col6" >0.63 ± 0.485</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_68a69_row6_col0" class="data row6 col0" >7.0</td>
#       <td id="T_68a69_row6_col1" class="data row6 col1" >3.08 ± 0.273</td>
#       <td id="T_68a69_row6_col2" class="data row6 col2" >439.229 ± 13.482</td>
#       <td id="T_68a69_row6_col3" class="data row6 col3" >0.77 ± 1.145</td>
#       <td id="T_68a69_row6_col4" class="data row6 col4" >5.7 ± 2.517</td>
#       <td id="T_68a69_row6_col5" class="data row6 col5" >1.39 ± 0.584</td>
#       <td id="T_68a69_row6_col6" class="data row6 col6" >0.2 ± 0.402</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_68a69_row7_col0" class="data row7 col0" >8.0</td>
#       <td id="T_68a69_row7_col1" class="data row7 col1" >4.03 ± 0.171</td>
#       <td id="T_68a69_row7_col2" class="data row7 col2" >501.103 ± 13.204</td>
#       <td id="T_68a69_row7_col3" class="data row7 col3" >4.02 ± 0.635</td>
#       <td id="T_68a69_row7_col4" class="data row7 col4" >8.83 ± 3.45</td>
#       <td id="T_68a69_row7_col5" class="data row7 col5" >1.3 ± 0.659</td>
#       <td id="T_68a69_row7_col6" class="data row7 col6" >0.97 ± 0.171</td>
#     </tr>
#     <tr>
#       <th id="T_68a69_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_68a69_row8_col0" class="data row8 col0" >9.0</td>
#       <td id="T_68a69_row8_col1" class="data row8 col1" >5.0</td>
#       <td id="T_68a69_row8_col2" class="data row8 col2" >562.845 ± 12.332</td>
#       <td id="T_68a69_row8_col3" class="data row8 col3" >1.89 ± 0.863</td>
#       <td id="T_68a69_row8_col4" class="data row8 col4" >3.2 ± 0.725</td>
#       <td id="T_68a69_row8_col5" class="data row8 col5" >2.25 ± 0.783</td>
#       <td id="T_68a69_row8_col6" class="data row8 col6" >0.44 ± 0.499</td>
#     </tr>
#   </tbody>
# </table>

# %%
action_df = action_dataframe.df

# %%
sparkle_action_df = action_df.loc[(action_df["Name"] == "Sparkle")].copy()

# %%
sparkle_action_df.iloc[:30]
# Out:
#        Name  Cycle  Action Gauge Current SP  Current Energy    Action SP Gain
# 0   Sparkle    0.0     62.111801          6           55.00     Skill      -1
# 4   Sparkle    0.0    124.223602          4           90.82     Skill      -1
# 5   Sparkle    0.0    124.323602          3          126.64  Ultimate       4
# 9   Sparkle    1.0    186.335404          4            5.00     Skill      -1
# 13  Sparkle    1.0    248.447205          1           40.82     Skill      -1
# 17  Sparkle    2.0    310.559006          1           76.64     Skill      -1
# 18  Sparkle    2.0    310.659006          0          112.46  Ultimate       4
# 22  Sparkle    3.0    372.670807          2            5.00     Skill      -1
# 26  Sparkle    3.0    434.782609          1           40.82     Skill      -1
# 30  Sparkle    4.0    496.894410          1           76.64     Skill      -1
# 31  Sparkle    4.0    496.994410          0          112.46  Ultimate       4
# 34  Sparkle    5.0    559.006211          2            5.00     Skill      -1
# 38  Sparkle    5.0    621.118012          1           40.82     Skill      -1
# 41  Sparkle    6.0    683.229814          0           76.64     Basic       1
# 42  Sparkle    0.0     62.111801          6           55.00     Skill      -1
# 46  Sparkle    0.0    124.223602          1           90.82     Skill      -1
# 47  Sparkle    0.0    124.323602          0          126.64  Ultimate       4
# 51  Sparkle    1.0    186.335404          1            5.00     Skill      -1
# 55  Sparkle    1.0    248.447205          1           40.82     Skill      -1
# 59  Sparkle    2.0    310.559006          1           76.64     Skill      -1
# 60  Sparkle    2.0    310.659006          0          112.46  Ultimate       4
# 64  Sparkle    3.0    372.670807          2            5.00     Skill      -1
# 68  Sparkle    3.0    434.782609          1           40.82     Skill      -1
# 72  Sparkle    4.0    496.894410          1           76.64     Skill      -1
# 73  Sparkle    4.0    496.994410          0          112.46  Ultimate       4
# 76  Sparkle    5.0    559.006211          3            5.00     Skill      -1
# 80  Sparkle    5.0    621.118012          1           40.82     Skill      -1
# 83  Sparkle    6.0    683.229814          0           76.64     Basic       1
# 84  Sparkle    0.0     62.111801          6           55.00     Skill      -1
# 88  Sparkle    0.0    124.223602          3           90.82     Skill      -1

# %%
spk_ult_df = sparkle_action_df.loc[sparkle_action_df["Action"] == "Ultimate"]

# %%
len(spk_ult_df.loc[spk_ult_df["Current Energy"] == 120.00])/len(spk_ult_df)
# Out:
# 0.13

# %%
action_df.loc[(action_df["Name"] != "Fu Xuan") & (action_df["Name"] != "Silver Wolf")].iloc[:20]
# Out:
#        Name  Cycle  Action Gauge Current SP  Current Energy          Action  \
# 0   Sparkle    0.0     62.111801          6           55.00           Skill
# 1   Qingque    0.0     62.211801          6           70.00  Enhanced Basic
# 4   Sparkle    0.0    124.223602          4           90.82           Skill
# 5   Sparkle    0.0    124.323602          3          126.64        Ultimate
# 6   Qingque    0.0    124.323602          7           70.00  Enhanced Basic
# 9   Sparkle    1.0    186.335404          4            5.00           Skill
# 10  Qingque    1.0    186.435404          3           70.00  Enhanced Basic
# 13  Sparkle    1.0    248.447205          1           40.82           Skill
# 14  Qingque    1.0    248.547205          0           70.00           Basic
# 17  Sparkle    2.0    310.559006          1           76.64           Skill
# 18  Sparkle    2.0    310.659006          0          112.46        Ultimate
# 19  Qingque    2.0    310.659006          4           70.00  Enhanced Basic
# 22  Sparkle    3.0    372.670807          2            5.00           Skill
# 23  Qingque    3.0    372.770807          1           70.00  Enhanced Basic
# 26  Sparkle    3.0    434.782609          1           40.82           Skill
# 27  Qingque    3.0    434.882609          0           70.00           Basic
# 30  Sparkle    4.0    496.894410          1           76.64           Skill
# 31  Sparkle    4.0    496.994410          0          112.46        Ultimate
# 32  Qingque    4.0    496.994410          4           70.00  Enhanced Basic
# 34  Sparkle    5.0    559.006211          2            5.00           Skill
#
#    SP Gain
# 0       -1
# 1        2
# 4       -1
# 5        4
# 6        3
# 9       -1
# 10       2
# 13      -1
# 14       1
# 17      -1
# 18       4
# 19       0
# 22      -1
# 23       0
# 26      -1
# 27       1
# 30      -1
# 31       4
# 32       1
# 34      -1

# %%
statistics_dataframe.df.iloc[:20]
# Out:
#    Sim # Turn  Cycle  Action Gauge Current SP Current Tiles # Draws  \
# 0      0    1    0.0     62.211801          6             2       3
# 1      0    2    0.0    124.323602          7             4       4
# 2      0    3    1.0    186.435404          3             4       3
# 3      0    4    1.0    248.547205          0             4       1
# 4      0    5    2.0    310.659006          4             8       1
# 5      0    6    3.0    372.770807          1             4       1
# 6      0    7    3.0    434.882609          0             4       1
# 7      0    8    4.0    496.994410          4             8       2
# 8      0    9    5.0    559.106211          1             3       2
# 9      0   10    5.0    621.218012          0             7       1
# 10     1    1    0.0     62.211801          6             2       6
# 11     1    2    0.0    124.323602          4             4       5
# 12     1    3    1.0    186.435404          0             8       1
# 13     1    4    1.0    248.547205          0            12       1
# 14     1    5    2.0    310.659006          4            16       1
# 15     1    6    3.0    372.770807          1             4       2
# 16     1    7    3.0    434.882609          0             8       1
# 17     1    8    4.0    496.994410          4            12       1
# 18     1    9    5.0    559.106211          2             3       3
# 19     1   10    5.0    621.218012          0             7       1
#
#    Hidden Hand
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
# 5         True
# 6        False
# 7         True
# 8        False
# 9        False
# 10        True
# 11       False
# 12       False
# 13       False
# 14        True
# 15       False
# 16       False
# 17        True
# 18       False
# 19       False

# %%
action_df.iloc[:30]
# Out:
#            Name  Cycle  Action Gauge Current SP  Current Energy  \
# 0       Sparkle    0.0     62.111801          6           55.00
# 1       Qingque    0.0     62.211801          6           70.00
# 2   Silver Wolf    0.0     68.493151          4           55.00
# 3       Fu Xuan    0.0     70.422535          3           67.50
# 4       Sparkle    0.0    124.223602          4           90.82
# 5       Sparkle    0.0    124.323602          3          126.64
# 6       Qingque    0.0    124.323602          7           70.00
# 7   Silver Wolf    0.0    136.986301          4           55.00
# 8       Fu Xuan    0.0    140.845070          3           91.38
# 9       Sparkle    1.0    186.335404          4            5.00
# 10      Qingque    1.0    186.435404          3           70.00
# 11  Silver Wolf    1.0    205.479452          1           55.00
# 12      Fu Xuan    1.0    211.267606          0          115.26
# 13      Sparkle    1.0    248.447205          1           40.82
# 14      Qingque    1.0    248.547205          0           70.00
# 15  Silver Wolf    2.0    273.972603         -1           55.00
# 16      Fu Xuan    2.0    281.690141          0          139.14
# 17      Sparkle    2.0    310.559006          1           76.64
# 18      Sparkle    2.0    310.659006          0          112.46
# 19      Qingque    2.0    310.659006          4           70.00
# 20  Silver Wolf    2.0    342.465753          4           55.00
# 21      Fu Xuan    3.0    352.112676          3          163.02
# 22      Sparkle    3.0    372.670807          2            5.00
# 23      Qingque    3.0    372.770807          1           70.00
# 24  Silver Wolf    3.0    410.958904          1           55.00
# 25      Fu Xuan    3.0    422.535211          0          163.02
# 26      Sparkle    3.0    434.782609          1           40.82
# 27      Qingque    3.0    434.882609          0           70.00
# 28  Silver Wolf    4.0    479.452055         -1           55.00
# 29      Fu Xuan    4.0    492.957746          0          186.90
#
#             Action SP Gain
# 0            Skill      -1
# 1   Enhanced Basic       2
# 2            Skill      -1
# 3            Basic       1
# 4            Skill      -1
# 5         Ultimate       4
# 6   Enhanced Basic       3
# 7            Skill      -1
# 8            Basic       1
# 9            Skill      -1
# 10  Enhanced Basic       2
# 11           Skill      -1
# 12           Basic       1
# 13           Skill      -1
# 14           Basic       1
# 15           Basic       1
# 16           Basic       1
# 17           Skill      -1
# 18        Ultimate       4
# 19  Enhanced Basic       0
# 20           Skill      -1
# 21           Skill      -1
# 22           Skill      -1
# 23  Enhanced Basic       0
# 24           Skill      -1
# 25           Basic       1
# 26           Skill      -1
# 27           Basic       1
# 28           Basic       1
# 29           Basic       1
