# %%
import numpy as np
import pandas as pd
from characters.sparkle import Sparkle
from characters.qingque import Qingque
from characters.silver_wolf import Silver_Wolf
from characters.fu_xuan import Fu_Xuan
from simulations.qingque_mono_quantum_looped import QQ_Mono_Quantum, Initialize_QQ_Mono_Quantum
from utils.arena import Arena
from utils.data_table import Action_Table, Qingque_Statistics_Table, Qingque_Probability_Table

# %% [markdown]
# # Character Imports

# %%
qingque_speed = 100.0

# %%
silver_wolf_speed = 139.2

# %%
sparkle_speed = 160.8
bronya_lc = False
sparkle_tech = True
sparkle_turn_1_skill = True

# %%
fu_xuan_speed = 138.8
fu_xuan_technique = True

# %% [markdown]
# # Simulations

# %%
arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, bronya_lc=bronya_lc)

# %%
action_dataframe = Action_Table()
statistics_dataframe = Qingque_Statistics_Table()
probability_dataframe = Qingque_Probability_Table()
trials = 100

# %%
ult_sp_threshold = 5
for run in range(trials):
    print(f"\rRun number = {run}", end='')
    arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, sparkle_turn_1_skill = sparkle_turn_1_skill)
    QQ_Mono_Quantum(arena, qq, spk, sw, fx, action_df=action_dataframe, stat_df= statistics_dataframe, prob_df = probability_dataframe, run_num=run, cycles=5 , ult_sp_threshold = ult_sp_threshold)
# Out:
# Run number = 1
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# Run number = 5
# Run number = 99

# %% [markdown]
# # Results

# %%
#statistics_dataframe.df

# %%
df = statistics_dataframe.df.copy()
start = df["Turn"].min()
end = df["Turn"].max()
columns = df.columns[1:]
summary_df = pd.DataFrame(columns=columns)
for turn in range(start, end):
    df_copy = df.copy()
    df_turn = df_copy.loc[df["Turn"] == turn]

    new_row_dict = {}
    for col in columns:
        mean = round(df_turn[col].mean(),3)
        std = round(df_turn[col].std(),3)
        if std != 0:
            entry = f"{mean} ± {std}"
        else:
            entry = f"{mean}"
        new_row_dict[col] = [entry]
    new_row = pd.DataFrame.from_dict(new_row_dict)
    summary_df = pd.concat([summary_df, new_row], ignore_index= True)

# %%
summary_df_styled = summary_df.style.set_caption(f"Qingque speed = {qingque_speed}, Sparkle speed = {sparkle_speed},  Silver Wolf Speed = {silver_wolf_speed}, Fu Xuan speed = {fu_xuan_speed}")
summary_df_styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_739af">
#   <caption>Qingque speed = 100.0, Sparkle speed = 160.8,  Silver Wolf Speed = 139.2, Fu Xuan speed = 138.8</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_739af_level0_col0" class="col_heading level0 col0" >Turn</th>
#       <th id="T_739af_level0_col1" class="col_heading level0 col1" >Cycle</th>
#       <th id="T_739af_level0_col2" class="col_heading level0 col2" >Action Gauge</th>
#       <th id="T_739af_level0_col3" class="col_heading level0 col3" >Current SP</th>
#       <th id="T_739af_level0_col4" class="col_heading level0 col4" >Current Tiles</th>
#       <th id="T_739af_level0_col5" class="col_heading level0 col5" ># Draws</th>
#       <th id="T_739af_level0_col6" class="col_heading level0 col6" >Hidden Hand</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_739af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_739af_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_739af_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_739af_row0_col2" class="data row0 col2" >62.289</td>
#       <td id="T_739af_row0_col3" class="data row0 col3" >6.0</td>
#       <td id="T_739af_row0_col4" class="data row0 col4" >2.0</td>
#       <td id="T_739af_row0_col5" class="data row0 col5" >2.96 ± 1.171</td>
#       <td id="T_739af_row0_col6" class="data row0 col6" >0.98 ± 0.141</td>
#     </tr>
#     <tr>
#       <th id="T_739af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_739af_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_739af_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_739af_row1_col2" class="data row1 col2" >124.478</td>
#       <td id="T_739af_row1_col3" class="data row1 col3" >6.69 ± 0.8</td>
#       <td id="T_739af_row1_col4" class="data row1 col4" >4.04 ± 0.281</td>
#       <td id="T_739af_row1_col5" class="data row1 col5" >2.0 ± 1.035</td>
#       <td id="T_739af_row1_col6" class="data row1 col6" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_739af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_739af_row2_col0" class="data row2 col0" >3.0</td>
#       <td id="T_739af_row2_col1" class="data row2 col1" >1.0</td>
#       <td id="T_739af_row2_col2" class="data row2 col2" >186.667</td>
#       <td id="T_739af_row2_col3" class="data row2 col3" >5.96 ± 1.044</td>
#       <td id="T_739af_row2_col4" class="data row2 col4" >4.0</td>
#       <td id="T_739af_row2_col5" class="data row2 col5" >2.17 ± 1.198</td>
#       <td id="T_739af_row2_col6" class="data row2 col6" >0.99 ± 0.1</td>
#     </tr>
#     <tr>
#       <th id="T_739af_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_739af_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_739af_row3_col1" class="data row3 col1" >1.0</td>
#       <td id="T_739af_row3_col2" class="data row3 col2" >248.856</td>
#       <td id="T_739af_row3_col3" class="data row3 col3" >4.27 ± 1.575</td>
#       <td id="T_739af_row3_col4" class="data row3 col4" >4.04 ± 0.4</td>
#       <td id="T_739af_row3_col5" class="data row3 col5" >2.18 ± 1.218</td>
#       <td id="T_739af_row3_col6" class="data row3 col6" >0.87 ± 0.338</td>
#     </tr>
#     <tr>
#       <th id="T_739af_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_739af_row4_col0" class="data row4 col0" >5.0</td>
#       <td id="T_739af_row4_col1" class="data row4 col1" >2.0</td>
#       <td id="T_739af_row4_col2" class="data row4 col2" >311.045</td>
#       <td id="T_739af_row4_col3" class="data row4 col3" >6.46 ± 1.672</td>
#       <td id="T_739af_row4_col4" class="data row4 col4" >4.56 ± 1.506</td>
#       <td id="T_739af_row4_col5" class="data row4 col5" >2.05 ± 1.209</td>
#       <td id="T_739af_row4_col6" class="data row4 col6" >1.0</td>
#     </tr>
#     <tr>
#       <th id="T_739af_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_739af_row5_col0" class="data row5 col0" >6.0</td>
#       <td id="T_739af_row5_col1" class="data row5 col1" >3.0</td>
#       <td id="T_739af_row5_col2" class="data row5 col2" >373.234</td>
#       <td id="T_739af_row5_col3" class="data row5 col3" >5.45 ± 1.52</td>
#       <td id="T_739af_row5_col4" class="data row5 col4" >4.0</td>
#       <td id="T_739af_row5_col5" class="data row5 col5" >2.31 ± 1.323</td>
#       <td id="T_739af_row5_col6" class="data row5 col6" >0.94 ± 0.239</td>
#     </tr>
#     <tr>
#       <th id="T_739af_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_739af_row6_col0" class="data row6 col0" >7.0</td>
#       <td id="T_739af_row6_col1" class="data row6 col1" >3.0</td>
#       <td id="T_739af_row6_col2" class="data row6 col2" >435.423</td>
#       <td id="T_739af_row6_col3" class="data row6 col3" >4.62 ± 1.78</td>
#       <td id="T_739af_row6_col4" class="data row6 col4" >4.24 ± 0.955</td>
#       <td id="T_739af_row6_col5" class="data row6 col5" >2.33 ± 1.24</td>
#       <td id="T_739af_row6_col6" class="data row6 col6" >0.86 ± 0.349</td>
#     </tr>
#     <tr>
#       <th id="T_739af_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_739af_row7_col0" class="data row7 col0" >8.0</td>
#       <td id="T_739af_row7_col1" class="data row7 col1" >4.0</td>
#       <td id="T_739af_row7_col2" class="data row7 col2" >502.906 ± 13.186</td>
#       <td id="T_739af_row7_col3" class="data row7 col3" >5.81 ± 1.873</td>
#       <td id="T_739af_row7_col4" class="data row7 col4" >3.08 ± 2.791</td>
#       <td id="T_739af_row7_col5" class="data row7 col5" >3.01 ± 1.275</td>
#       <td id="T_739af_row7_col6" class="data row7 col6" >0.95 ± 0.219</td>
#     </tr>
#     <tr>
#       <th id="T_739af_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_739af_row8_col0" class="data row8 col0" >9.0</td>
#       <td id="T_739af_row8_col1" class="data row8 col1" >5.0</td>
#       <td id="T_739af_row8_col2" class="data row8 col2" >564.888 ± 12.691</td>
#       <td id="T_739af_row8_col3" class="data row8 col3" >3.71 ± 2.367</td>
#       <td id="T_739af_row8_col4" class="data row8 col4" >4.28 ± 1.326</td>
#       <td id="T_739af_row8_col5" class="data row8 col5" >1.99 ± 1.115</td>
#       <td id="T_739af_row8_col6" class="data row8 col6" >0.71 ± 0.456</td>
#     </tr>
#   </tbody>
# </table>

# %%
action_df = action_dataframe.df

# %%
sparkle_action_df = action_df.loc[(action_df["Name"] == "Sparkle")].copy()

# %%
sparkle_action_df.iloc[:30]
# Out:
#        Name  Cycle  Action Gauge Current SP  Current Energy    Action SP Gain
# 0   Sparkle    0.0     62.189055          6           55.00     Skill      -1
# 4   Sparkle    0.0    124.378109          3           90.82     Skill      -1
# 5   Sparkle    0.0    124.478109          2          126.64  Ultimate       4
# 9   Sparkle    1.0    186.567164          7            5.00     Skill      -1
# 13  Sparkle    1.0    248.756219          6           40.82     Skill      -1
# 17  Sparkle    2.0    310.945274          3           76.64     Skill      -1
# 18  Sparkle    2.0    311.045274          2          112.46  Ultimate       4
# 22  Sparkle    3.0    373.134328          7            5.00     Skill      -1
# 26  Sparkle    3.0    435.323383          7           40.82     Skill      -1
# 28  Sparkle    4.0    497.512438          6           76.64     Skill      -1
# 32  Sparkle    5.0    559.701493          4          120.00  Ultimate       4
# 33  Sparkle    5.0    559.701493          8            5.00     Skill      -1
# 37  Sparkle    5.0    621.890547          7           40.82     Skill      -1
# 41  Sparkle    6.0    684.079602          7           76.64     Skill      -1
# 42  Sparkle    0.0     62.189055          6           55.00     Skill      -1
# 46  Sparkle    0.0    124.378109          5           90.82     Skill      -1
# 50  Sparkle    1.0    186.567164          5          120.00  Ultimate       4
# 51  Sparkle    1.0    186.567164          9            5.00     Skill      -1
# 55  Sparkle    1.0    248.756219          7           40.82     Skill      -1
# 59  Sparkle    2.0    310.945274          7           76.64     Skill      -1
# 63  Sparkle    3.0    373.134328          5          120.00  Ultimate       4
# 64  Sparkle    3.0    373.134328          9            5.00     Skill      -1
# 68  Sparkle    3.0    435.323383          7           40.82     Skill      -1
# 70  Sparkle    4.0    497.512438          6           76.64     Skill      -1
# 74  Sparkle    5.0    559.701493          4          120.00  Ultimate       4
# 75  Sparkle    5.0    559.701493          8            5.00     Skill      -1
# 79  Sparkle    5.0    621.890547          6           40.82     Skill      -1
# 83  Sparkle    6.0    684.079602          5           76.64     Skill      -1
# 84  Sparkle    0.0     62.189055          6           55.00     Skill      -1
# 88  Sparkle    0.0    124.378109          4           90.82     Skill      -1

# %%
spk_ult_df = sparkle_action_df.loc[sparkle_action_df["Action"] == "Ultimate"]

# %%
len(spk_ult_df.loc[spk_ult_df["Current Energy"] == 120.00])/len(spk_ult_df)
# Out:
# 0.3566666666666667

# %%
action_df.loc[(action_df["Name"] != "Fu Xuan") & (action_df["Name"] != "Silver Wolf")].iloc[:20]
# Out:
#        Name  Cycle  Action Gauge Current SP  Current Energy          Action  \
# 0   Sparkle    0.0     62.189055          6           55.00           Skill
# 1   Qingque    0.0     62.289055          6           70.00  Enhanced Basic
# 4   Sparkle    0.0    124.378109          3           90.82           Skill
# 5   Sparkle    0.0    124.478109          2          126.64        Ultimate
# 6   Qingque    0.0    124.478109          6           70.00  Enhanced Basic
# 9   Sparkle    1.0    186.567164          7            5.00           Skill
# 10  Qingque    1.0    186.667164          6           70.00  Enhanced Basic
# 13  Sparkle    1.0    248.756219          6           40.82           Skill
# 14  Qingque    1.0    248.856219          5           70.00  Enhanced Basic
# 17  Sparkle    2.0    310.945274          3           76.64           Skill
# 18  Sparkle    2.0    311.045274          2          112.46        Ultimate
# 19  Qingque    2.0    311.045274          6           70.00  Enhanced Basic
# 22  Sparkle    3.0    373.134328          7            5.00           Skill
# 23  Qingque    3.0    373.234328          6           70.00  Enhanced Basic
# 26  Sparkle    3.0    435.323383          7           40.82           Skill
# 27  Qingque    3.0    435.423383          6           70.00  Enhanced Basic
# 28  Sparkle    4.0    497.512438          6           76.64           Skill
# 29  Qingque    4.0    497.612438          9           70.00  Enhanced Basic
# 32  Sparkle    5.0    559.701493          4          120.00        Ultimate
# 33  Sparkle    5.0    559.701493          8            5.00           Skill
#
#    SP Gain
# 0       -1
# 1        3
# 4       -1
# 5        4
# 6        1
# 9       -1
# 10       0
# 13      -1
# 14       2
# 17      -1
# 18       4
# 19       0
# 22      -1
# 23       0
# 26      -1
# 27       0
# 28      -1
# 29       2
# 32       4
# 33      -1

# %%
statistics_dataframe.df.iloc[:20]
# Out:
#    Sim # Turn  Cycle  Action Gauge Current SP Current Tiles # Draws  \
# 0      0    1    0.0     62.289055          6             2       4
# 1      0    2    0.0    124.478109          6             4       2
# 2      0    3    1.0    186.667164          6             4       1
# 3      0    4    1.0    248.856219          5             4       3
# 4      0    5    2.0    311.045274          6             4       1
# 5      0    6    3.0    373.234328          6             4       1
# 6      0    7    3.0    435.423383          6             4       1
# 7      0    8    4.0    497.612438          8             2       3
# 8      0    9    5.0    559.801493          7             4       3
# 9      0   10    5.0    621.990547          6             4       2
# 10     1    1    0.0     62.289055          6             2       2
# 11     1    2    0.0    124.478109          7             4       1
# 12     1    3    1.0    186.667164          7             4       3
# 13     1    4    1.0    248.856219          6             4       1
# 14     1    5    2.0    311.045274          9             4       2
# 15     1    6    3.0    373.234328          7             4       1
# 16     1    7    3.0    435.423383          6             4       1
# 17     1    8    4.0    497.612438          8             2       3
# 18     1    9    5.0    559.801493          7             4       4
# 19     1   10    5.0    621.990547          5             4       3
#
#    Hidden Hand
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True

# %%
action_df.iloc[:30]
# Out:
#            Name  Cycle  Action Gauge Current SP  Current Energy  \
# 0       Sparkle    0.0     62.189055          6           55.00
# 1       Qingque    0.0     62.289055          6           70.00
# 2   Silver Wolf    0.0     71.839080          3           55.00
# 3       Fu Xuan    0.0     72.046110          2           67.50
# 4       Sparkle    0.0    124.378109          3           90.82
# 5       Sparkle    0.0    124.478109          2          126.64
# 6       Qingque    0.0    124.478109          6           70.00
# 7   Silver Wolf    0.0    143.678161          5           55.00
# 8       Fu Xuan    0.0    144.092219          6           91.38
# 9       Sparkle    1.0    186.567164          7            5.00
# 10      Qingque    1.0    186.667164          6           70.00
# 11  Silver Wolf    1.0    215.517241          6           55.00
# 12      Fu Xuan    1.0    216.138329          7          115.26
# 13      Sparkle    1.0    248.756219          6           40.82
# 14      Qingque    1.0    248.856219          5           70.00
# 15  Silver Wolf    2.0    287.356322          3           55.00
# 16      Fu Xuan    2.0    288.184438          2          115.26
# 17      Sparkle    2.0    310.945274          3           76.64
# 18      Sparkle    2.0    311.045274          2          112.46
# 19      Qingque    2.0    311.045274          6           70.00
# 20  Silver Wolf    3.0    359.195402          6           55.00
# 21      Fu Xuan    3.0    360.230548          7          139.14
# 22      Sparkle    3.0    373.134328          7            5.00
# 23      Qingque    3.0    373.234328          6           70.00
# 24  Silver Wolf    3.0    431.034483          6           55.00
# 25      Fu Xuan    3.0    432.276657          7          163.02
# 26      Sparkle    3.0    435.323383          7           40.82
# 27      Qingque    3.0    435.423383          6           70.00
# 28      Sparkle    4.0    497.512438          6           76.64
# 29      Qingque    4.0    497.612438          9           70.00
#
#             Action SP Gain
# 0            Skill      -1
# 1   Enhanced Basic       3
# 2            Skill      -1
# 3            Basic       1
# 4            Skill      -1
# 5         Ultimate       4
# 6   Enhanced Basic       1
# 7            Basic       1
# 8            Basic       1
# 9            Skill      -1
# 10  Enhanced Basic       0
# 11           Basic       1
# 12           Skill      -1
# 13           Skill      -1
# 14  Enhanced Basic       2
# 15           Skill      -1
# 16           Basic       1
# 17           Skill      -1
# 18        Ultimate       4
# 19  Enhanced Basic       0
# 20           Basic       1
# 21           Basic       1
# 22           Skill      -1
# 23  Enhanced Basic       0
# 24           Basic       1
# 25           Basic       1
# 26           Skill      -1
# 27  Enhanced Basic       0
# 28           Skill      -1
# 29  Enhanced Basic       2
