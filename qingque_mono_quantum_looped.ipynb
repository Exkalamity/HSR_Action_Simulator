# %%
import numpy as np
import pandas as pd
from characters.sparkle import Sparkle
from characters.qingque import Qingque
from characters.silver_wolf import Silver_Wolf
from characters.fu_xuan import Fu_Xuan
from simulations.qingque_mono_quantum_looped import QQ_Mono_Quantum, Initialize_QQ_Mono_Quantum
from utils.arena import Arena
from utils.data_table import Action_Table, Qingque_Statistics_Table, Qingque_Probability_Table

# %% [markdown]
# # Character Imports

# %%
qingque_speed = 98

# %%
silver_wolf_speed = 161

# %%
sparkle_speed = 162
bronya_lc = False
sparkle_tech = True
sparkle_turn_1_skill = True

# %%
fu_xuan_speed = 129
fu_xuan_technique = True

# %% [markdown]
# # Simulations

# %%
arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, bronya_lc=bronya_lc)

# %%
action_dataframe = Action_Table()
statistics_dataframe = Qingque_Statistics_Table()
probability_dataframe = Qingque_Probability_Table()
trials = 400

# %%
ult_sp_threshold = 5
for run in range(trials):
    print(f"\rRun number = {run}", end='')
    arena, qq, spk, sw, fx = Initialize_QQ_Mono_Quantum(qingque_speed=qingque_speed, fu_xuan_speed=fu_xuan_speed, sparkle_speed=sparkle_speed, silver_wolf_speed=silver_wolf_speed, sparkle_turn_1_skill = sparkle_turn_1_skill)
    QQ_Mono_Quantum(arena, qq, spk, sw, fx, action_df=action_dataframe, stat_df= statistics_dataframe, prob_df = probability_dataframe, run_num=run, cycles=5 , ult_sp_threshold = ult_sp_threshold)
# Out:
# Run number = 1
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:18: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# c:\Users\rainf\OneDrive\Documents\Git Projects\HSR_Action_Simulator-1\utils\data_table.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   self.df = pd.concat([self.df, pd.DataFrame([new_row])], ignore_index = True)
# Run number = 10
# Run number = 399

# %% [markdown]
# # Results

# %%
#statistics_dataframe.df

# %%
df = statistics_dataframe.df.copy()
start = df["Turn"].min()
end = df["Turn"].max()
columns = df.columns[1:]
summary_df = pd.DataFrame()
for turn in range(start, end):
    df_copy = df.copy()
    df_turn = df_copy.loc[df["Turn"] == turn]

    new_row_dict = {}
    for col in columns:
        mean = round(df_turn[col].mean(),3)
        ci = round(df_turn[col].std() *1.96/np.sqrt(trials),3)
        std = round(df_turn[col].std(),3)
        if ci != 0:
            entry = f"{mean} ± {ci}"
        else:
            entry = f"{mean}"
        new_row_dict[col] = [entry]
        #new_row_dict[col + " std"] = [std]
    new_row = pd.DataFrame.from_dict(new_row_dict)
    summary_df = pd.concat([summary_df, new_row], ignore_index= True)
summary_df.index += 1

# %%
# Get the HTML of the styled DataFrame
summary_df_styled = summary_df.style.set_caption(f"Qingque speed = {qingque_speed}, Sparkle speed = {sparkle_speed},  Silver Wolf Speed = {silver_wolf_speed}, Fu Xuan speed = {fu_xuan_speed}")
html = summary_df_styled.to_html()

# Insert the title at the top
title = '<h2>QQ Probability Parameters w/ 95% confidence intervals</h2>'
html = html.replace('<table', title + '<table')

# Display the HTML
from IPython.display import display, HTML
display(HTML(html))
# Out:
# <style type="text/css">
# </style>
# <h2>QQ Probability Parameters w/ 95% confidence intervals</h2><table id="T_55941">
#   <caption>Qingque speed = 98, Sparkle speed = 162,  Silver Wolf Speed = 161, Fu Xuan speed = 129</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55941_level0_col0" class="col_heading level0 col0" >Turn</th>
#       <th id="T_55941_level0_col1" class="col_heading level0 col1" >Cycle</th>
#       <th id="T_55941_level0_col2" class="col_heading level0 col2" >Action Gauge</th>
#       <th id="T_55941_level0_col3" class="col_heading level0 col3" >Current SP</th>
#       <th id="T_55941_level0_col4" class="col_heading level0 col4" >Current Tiles</th>
#       <th id="T_55941_level0_col5" class="col_heading level0 col5" ># Draws</th>
#       <th id="T_55941_level0_col6" class="col_heading level0 col6" >Hidden Hand Win Rate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55941_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_55941_row0_col0" class="data row0 col0" >1.0</td>
#       <td id="T_55941_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_55941_row0_col2" class="data row0 col2" >61.828</td>
#       <td id="T_55941_row0_col3" class="data row0 col3" >6.0</td>
#       <td id="T_55941_row0_col4" class="data row0 col4" >2.0</td>
#       <td id="T_55941_row0_col5" class="data row0 col5" >3.205 ± 0.118</td>
#       <td id="T_55941_row0_col6" class="data row0 col6" >0.972 ± 0.016</td>
#     </tr>
#     <tr>
#       <th id="T_55941_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_55941_row1_col0" class="data row1 col0" >2.0</td>
#       <td id="T_55941_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_55941_row1_col2" class="data row1 col2" >123.557</td>
#       <td id="T_55941_row1_col3" class="data row1 col3" >7.898 ± 0.091</td>
#       <td id="T_55941_row1_col4" class="data row1 col4" >4.055 ± 0.032</td>
#       <td id="T_55941_row1_col5" class="data row1 col5" >2.35 ± 0.136</td>
#       <td id="T_55941_row1_col6" class="data row1 col6" >0.992 ± 0.008</td>
#     </tr>
#     <tr>
#       <th id="T_55941_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_55941_row2_col0" class="data row2 col0" >3.0</td>
#       <td id="T_55941_row2_col1" class="data row2 col1" >1.0</td>
#       <td id="T_55941_row2_col2" class="data row2 col2" >185.285</td>
#       <td id="T_55941_row2_col3" class="data row2 col3" >5.79 ± 0.068</td>
#       <td id="T_55941_row2_col4" class="data row2 col4" >4.03 ± 0.034</td>
#       <td id="T_55941_row2_col5" class="data row2 col5" >2.332 ± 0.121</td>
#       <td id="T_55941_row2_col6" class="data row2 col6" >0.982 ± 0.013</td>
#     </tr>
#     <tr>
#       <th id="T_55941_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_55941_row3_col0" class="data row3 col0" >4.0</td>
#       <td id="T_55941_row3_col1" class="data row3 col1" >1.0</td>
#       <td id="T_55941_row3_col2" class="data row3 col2" >247.014</td>
#       <td id="T_55941_row3_col3" class="data row3 col3" >4.868 ± 0.135</td>
#       <td id="T_55941_row3_col4" class="data row3 col4" >4.07 ± 0.051</td>
#       <td id="T_55941_row3_col5" class="data row3 col5" >2.178 ± 0.115</td>
#       <td id="T_55941_row3_col6" class="data row3 col6" >0.948 ± 0.022</td>
#     </tr>
#     <tr>
#       <th id="T_55941_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_55941_row4_col0" class="data row4 col0" >5.0</td>
#       <td id="T_55941_row4_col1" class="data row4 col1" >2.0</td>
#       <td id="T_55941_row4_col2" class="data row4 col2" >308.742</td>
#       <td id="T_55941_row4_col3" class="data row4 col3" >7.08 ± 0.114</td>
#       <td id="T_55941_row4_col4" class="data row4 col4" >3.23 ± 0.099</td>
#       <td id="T_55941_row4_col5" class="data row4 col5" >2.608 ± 0.125</td>
#       <td id="T_55941_row4_col6" class="data row4 col6" >0.982 ± 0.013</td>
#     </tr>
#     <tr>
#       <th id="T_55941_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_55941_row5_col0" class="data row5 col0" >6.0</td>
#       <td id="T_55941_row5_col1" class="data row5 col1" >3.0</td>
#       <td id="T_55941_row5_col2" class="data row5 col2" >370.47</td>
#       <td id="T_55941_row5_col3" class="data row5 col3" >5.035 ± 0.137</td>
#       <td id="T_55941_row5_col4" class="data row5 col4" >4.072 ± 0.058</td>
#       <td id="T_55941_row5_col5" class="data row5 col5" >2.2 ± 0.119</td>
#       <td id="T_55941_row5_col6" class="data row5 col6" >0.925 ± 0.026</td>
#     </tr>
#     <tr>
#       <th id="T_55941_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_55941_row6_col0" class="data row6 col0" >7.0</td>
#       <td id="T_55941_row6_col1" class="data row6 col1" >3.0</td>
#       <td id="T_55941_row6_col2" class="data row6 col2" >432.199</td>
#       <td id="T_55941_row6_col3" class="data row6 col3" >4.595 ± 0.147</td>
#       <td id="T_55941_row6_col4" class="data row6 col4" >4.34 ± 0.124</td>
#       <td id="T_55941_row6_col5" class="data row6 col5" >2.075 ± 0.109</td>
#       <td id="T_55941_row6_col6" class="data row6 col6" >0.935 ± 0.024</td>
#     </tr>
#     <tr>
#       <th id="T_55941_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_55941_row7_col0" class="data row7 col0" >8.0</td>
#       <td id="T_55941_row7_col1" class="data row7 col1" >4.0</td>
#       <td id="T_55941_row7_col2" class="data row7 col2" >493.927</td>
#       <td id="T_55941_row7_col3" class="data row7 col3" >7.15 ± 0.158</td>
#       <td id="T_55941_row7_col4" class="data row7 col4" >4.26 ± 0.097</td>
#       <td id="T_55941_row7_col5" class="data row7 col5" >2.265 ± 0.129</td>
#       <td id="T_55941_row7_col6" class="data row7 col6" >0.98 ± 0.014</td>
#     </tr>
#     <tr>
#       <th id="T_55941_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_55941_row8_col0" class="data row8 col0" >9.0</td>
#       <td id="T_55941_row8_col1" class="data row8 col1" >5.0</td>
#       <td id="T_55941_row8_col2" class="data row8 col2" >555.656</td>
#       <td id="T_55941_row8_col3" class="data row8 col3" >4.795 ± 0.163</td>
#       <td id="T_55941_row8_col4" class="data row8 col4" >4.09 ± 0.064</td>
#       <td id="T_55941_row8_col5" class="data row8 col5" >2.022 ± 0.124</td>
#       <td id="T_55941_row8_col6" class="data row8 col6" >0.888 ± 0.031</td>
#     </tr>
#   </tbody>
# </table>

# %%
action_df = action_dataframe.df

# %%
action_df.iloc[:30]
# Out:
#            Name  Cycle  Action Gauge Current SP  Current Energy  \
# 0       Sparkle    0.0     61.728395          6           55.00
# 1       Qingque    0.0     61.828395          6           70.00
# 2   Silver Wolf    0.0     62.111801          4           55.00
# 3       Fu Xuan    0.0     77.519380          5           67.50
# 4       Sparkle    0.0    123.456790          6           90.82
# 5       Qingque    0.0    123.556790          9           70.00
# 6   Silver Wolf    0.0    124.223602          5           55.00
# 7       Fu Xuan    1.0    155.038760          4           91.38
# 8       Sparkle    1.0    185.185185          3          120.00
# 9       Sparkle    1.0    185.185185          7            5.00
# 10      Qingque    1.0    185.285185          6           70.00
# 11  Silver Wolf    1.0    186.335404          4           55.00
# 12      Fu Xuan    1.0    232.558140          5           91.38
# 13      Sparkle    1.0    246.913580          6           40.82
# 14      Qingque    1.0    247.013580          5           70.00
# 15  Silver Wolf    1.0    248.447205          4           55.00
# 16      Sparkle    2.0    308.641975          5           76.64
# 17      Qingque    2.0    308.741975          8           70.00
# 18      Fu Xuan    2.0    310.077519          5          115.26
# 19  Silver Wolf    2.0    310.559006          4           55.00
# 20      Sparkle    3.0    370.370370          3          120.00
# 21      Sparkle    3.0    370.370370          7            5.00
# 22      Qingque    3.0    370.470370          6           70.00
# 23  Silver Wolf    3.0    372.670807          5           55.00
# 24      Fu Xuan    3.0    387.596899          6          115.26
# 25      Sparkle    3.0    432.098765          7           40.82
# 26      Qingque    3.0    432.198765          6           70.00
# 27  Silver Wolf    3.0    434.782609          3           55.00
# 28      Fu Xuan    4.0    465.116279          4          139.14
# 29      Sparkle    4.0    493.827160          5           76.64
#
#             Action SP Gain
# 0            Skill      -1
# 1   Enhanced Basic       2
# 2            Basic       1
# 3            Basic       1
# 4            Skill      -1
# 5   Enhanced Basic       3
# 6            Skill      -1
# 7            Skill      -1
# 8         Ultimate       4
# 9            Skill      -1
# 10  Enhanced Basic       2
# 11           Basic       1
# 12           Basic       1
# 13           Skill      -1
# 14  Enhanced Basic       1
# 15           Basic       1
# 16           Skill      -1
# 17  Enhanced Basic       2
# 18           Skill      -1
# 19           Skill      -1
# 20        Ultimate       4
# 21           Skill      -1
# 22  Enhanced Basic       1
# 23           Basic       1
# 24           Basic       1
# 25           Skill      -1
# 26  Enhanced Basic       3
# 27           Basic       1
# 28           Basic       1
# 29           Skill      -1

# %%
sparkle_action_df = action_df.loc[(action_df["Name"] == "Sparkle")].copy()

# %%
sparkle_action_df.iloc[:30]
# Out:
#        Name  Cycle  Action Gauge Current SP  Current Energy    Action SP Gain
# 0   Sparkle    0.0     61.728395          6           55.00     Skill      -1
# 4   Sparkle    0.0    123.456790          6           90.82     Skill      -1
# 8   Sparkle    1.0    185.185185          3          120.00  Ultimate       4
# 9   Sparkle    1.0    185.185185          7            5.00     Skill      -1
# 13  Sparkle    1.0    246.913580          6           40.82     Skill      -1
# 16  Sparkle    2.0    308.641975          5           76.64     Skill      -1
# 20  Sparkle    3.0    370.370370          3          120.00  Ultimate       4
# 21  Sparkle    3.0    370.370370          7            5.00     Skill      -1
# 25  Sparkle    3.0    432.098765          7           40.82     Skill      -1
# 29  Sparkle    4.0    493.827160          5           76.64     Skill      -1
# 33  Sparkle    5.0    555.555556          5          120.00  Ultimate       4
# 34  Sparkle    5.0    555.555556          7            5.00     Skill      -1
# 37  Sparkle    5.0    617.283951          5           40.82     Skill      -1
# 41  Sparkle    6.0    679.012346          5           76.64     Skill      -1
# 42  Sparkle    0.0     61.728395          6           55.00     Skill      -1
# 46  Sparkle    0.0    123.456790          6           90.82     Skill      -1
# 50  Sparkle    1.0    185.185185          4          120.00  Ultimate       4
# 51  Sparkle    1.0    185.185185          7            5.00     Skill      -1
# 55  Sparkle    1.0    246.913580          6           40.82     Skill      -1
# 58  Sparkle    2.0    308.641975          6           76.64     Skill      -1
# 62  Sparkle    3.0    370.370370          4          120.00  Ultimate       4
# 63  Sparkle    3.0    370.370370          7            5.00     Skill      -1
# 67  Sparkle    3.0    432.098765          7           40.82     Skill      -1
# 71  Sparkle    4.0    493.827160          6           76.64     Skill      -1
# 75  Sparkle    5.0    555.555556          5          120.00  Ultimate       4
# 76  Sparkle    5.0    555.555556          7            5.00     Skill      -1
# 79  Sparkle    5.0    617.283951          4           40.82     Skill      -1
# 83  Sparkle    6.0    679.012346          3           76.64     Skill      -1
# 84  Sparkle    0.0     61.728395          6           55.00     Skill      -1
# 88  Sparkle    0.0    123.456790          6           90.82     Skill      -1

# %%
spk_ult_df = sparkle_action_df.loc[sparkle_action_df["Action"] == "Ultimate"]

# %%
len(spk_ult_df.loc[spk_ult_df["Current Energy"] == 120.00])/len(spk_ult_df)
# Out:
# 0.6508333333333334

# %%
action_df.loc[(action_df["Name"] != "Fu Xuan") & (action_df["Name"] != "Silver Wolf")].iloc[:20]
# Out:
#        Name  Cycle  Action Gauge Current SP  Current Energy          Action  \
# 0   Sparkle    0.0     61.728395          6           55.00           Skill
# 1   Qingque    0.0     61.828395          6           70.00  Enhanced Basic
# 4   Sparkle    0.0    123.456790          6           90.82           Skill
# 5   Qingque    0.0    123.556790          9           70.00  Enhanced Basic
# 8   Sparkle    1.0    185.185185          3          120.00        Ultimate
# 9   Sparkle    1.0    185.185185          7            5.00           Skill
# 10  Qingque    1.0    185.285185          6           70.00  Enhanced Basic
# 13  Sparkle    1.0    246.913580          6           40.82           Skill
# 14  Qingque    1.0    247.013580          5           70.00  Enhanced Basic
# 16  Sparkle    2.0    308.641975          5           76.64           Skill
# 17  Qingque    2.0    308.741975          8           70.00  Enhanced Basic
# 20  Sparkle    3.0    370.370370          3          120.00        Ultimate
# 21  Sparkle    3.0    370.370370          7            5.00           Skill
# 22  Qingque    3.0    370.470370          6           70.00  Enhanced Basic
# 25  Sparkle    3.0    432.098765          7           40.82           Skill
# 26  Qingque    3.0    432.198765          6           70.00  Enhanced Basic
# 29  Sparkle    4.0    493.827160          5           76.64           Skill
# 30  Qingque    4.0    493.927160          8           70.00  Enhanced Basic
# 33  Sparkle    5.0    555.555556          5          120.00        Ultimate
# 34  Sparkle    5.0    555.555556          7            5.00           Skill
#
#    SP Gain
# 0       -1
# 1        2
# 4       -1
# 5        3
# 8        4
# 9       -1
# 10       2
# 13      -1
# 14       1
# 16      -1
# 17       2
# 20       4
# 21      -1
# 22       1
# 25      -1
# 26       3
# 29      -1
# 30       0
# 33       4
# 34      -1

# %%
statistics_dataframe.df.iloc[:20]
# Out:
#    Sim # Turn  Cycle  Action Gauge Current SP Current Tiles # Draws  \
# 0      0    1    0.0     61.828395          6             2       3
# 1      0    2    0.0    123.556790          8             4       4
# 2      0    3    1.0    185.285185          6             4       3
# 3      0    4    1.0    247.013580          5             4       2
# 4      0    5    2.0    308.741975          7             3       3
# 5      0    6    3.0    370.470370          6             4       2
# 6      0    7    3.0    432.198765          6             4       4
# 7      0    8    4.0    493.927160          7             4       1
# 8      0    9    5.0    555.655556          6             4       3
# 9      0   10    5.0    617.383951          4             3       2
# 10     1    1    0.0     61.828395          6             2       3
# 11     1    2    0.0    123.556790          8             4       3
# 12     1    3    1.0    185.285185          6             4       3
# 13     1    4    1.0    247.013580          5             4       1
# 14     1    5    2.0    308.741975          8             3       3
# 15     1    6    3.0    370.470370          6             4       1
# 16     1    7    3.0    432.198765          6             4       3
# 17     1    8    4.0    493.927160          8             4       2
# 18     1    9    5.0    555.655556          6             4       4
# 19     1   10    5.0    617.383951          3             3       3
#
#    Hidden Hand Win Rate
# 0                  True
# 1                  True
# 2                  True
# 3                  True
# 4                  True
# 5                  True
# 6                  True
# 7                  True
# 8                  True
# 9                  True
# 10                 True
# 11                 True
# 12                 True
# 13                 True
# 14                 True
# 15                 True
# 16                 True
# 17                 True
# 18                 True
# 19                 True

# %%
action_df = action_dataframe.df
action_df.loc[(action_df["Action Gauge"] > 200) & (action_df["Action Gauge"] < 300)].iloc[:30]
# Out:
#             Name  Cycle  Action Gauge Current SP  Current Energy  \
# 12       Fu Xuan    1.0    232.558140          5           91.38
# 13       Sparkle    1.0    246.913580          6           40.82
# 14       Qingque    1.0    247.013580          5           70.00
# 15   Silver Wolf    1.0    248.447205          4           55.00
# 54       Fu Xuan    1.0    232.558140          5           91.38
# 55       Sparkle    1.0    246.913580          6           40.82
# 56       Qingque    1.0    247.013580          5           70.00
# 57   Silver Wolf    1.0    248.447205          5           55.00
# 96       Fu Xuan    1.0    232.558140          3           91.38
# 97       Sparkle    1.0    246.913580          4           40.82
# 98       Qingque    1.0    247.013580          3           70.00
# 99   Silver Wolf    1.0    248.447205          1           55.00
# 138      Fu Xuan    1.0    232.558140          5           91.38
# 139      Sparkle    1.0    246.913580          6           40.82
# 140      Qingque    1.0    247.013580          5           70.00
# 141  Silver Wolf    1.0    248.447205          5           55.00
# 180      Fu Xuan    1.0    232.558140          5          115.26
# 181      Sparkle    1.0    246.913580          4           40.82
# 182      Qingque    1.0    247.013580          3           70.00
# 183  Silver Wolf    1.0    248.447205          3           55.00
# 222      Fu Xuan    1.0    232.558140          7           91.38
# 223      Sparkle    1.0    246.913580          7           40.82
# 224      Qingque    1.0    247.013580          6           70.00
# 225  Silver Wolf    1.0    248.447205          6           55.00
# 264      Fu Xuan    1.0    232.558140          7          115.26
# 265      Sparkle    1.0    246.913580          6           40.82
# 266      Qingque    1.0    247.013580          5           70.00
# 267  Silver Wolf    1.0    248.447205          4           55.00
# 306      Fu Xuan    1.0    232.558140          6           91.38
# 307      Sparkle    1.0    246.913580          7           40.82
#
#              Action SP Gain
# 12            Basic       1
# 13            Skill      -1
# 14   Enhanced Basic       1
# 15            Basic       1
# 54            Basic       1
# 55            Skill      -1
# 56   Enhanced Basic       0
# 57            Basic       1
# 96            Basic       1
# 97            Skill      -1
# 98            Basic       2
# 99            Basic       1
# 138           Basic       1
# 139           Skill      -1
# 140  Enhanced Basic       0
# 141           Basic       1
# 180           Skill      -1
# 181           Skill      -1
# 182  Enhanced Basic       0
# 183           Basic       1
# 222           Basic       1
# 223           Skill      -1
# 224  Enhanced Basic       0
# 225           Basic       1
# 264           Skill      -1
# 265           Skill      -1
# 266  Enhanced Basic       1
# 267           Basic       1
# 306           Basic       1
# 307           Skill      -1
